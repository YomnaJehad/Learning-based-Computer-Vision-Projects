# %% [markdown]
# ## Getting Started
#
# #### - We want to work with characters ’o’,’q’,’G’ and digit ’8’ which can be found in subdirectories Sample051, Sample053, Sample017 and Sample009, respectively.

# %%
import PIL
import numpy as np
import os
from PIL import Image
from numpy import asarray
from matplotlib import pyplot

#  Load the images into numpy matrices.

path = 'EnglishImg/English/Img/BadImag/Bmp/'
o_path = 'Sample051'
q_path = 'Sample053'
G_path = 'Sample017'
n8_path = 'Sample009'

paths = [o_path, q_path, G_path, n8_path]

o_array = []
q_array = []
G_array = []
n8_array = []

images_list = [o_array, q_array, G_array, n8_array]
images_array = np.array([np.array([]),np.array([]),np.array([]),np.array([])])
for i in range (0,4):
    
    dirs = os.listdir( path+paths[i] )
    print('Numebr of images in',paths[i],': ' ,len(dirs))
    
    for item in dirs:
        image = Image.open(path+paths[i]+'/'+item)
        resized = image.resize((32,32), Image.ANTIALIAS)
#         pyplot.imshow(resized)
#         pyplot.show()
        images_list[i].append(asarray(resized))
#         images_array[i] = np.insert( (
#             images_array[i],images_array[i].shape[0],asarray(resized)
#                                      ) )
#         images_array[i] = np.concatenate( (images_array[i], asarray(resized)), axis=0 )
        #print(images_array[i].shape)
        #print(len(images_list[i]), len(images_list[i][0], len(images_list[i][1])))
        
len(images_list[0][109][31][31])
print( 'RGB??: ', images_list[0][109][31][31][0], images_list[0][109][31][31][1], images_list[0][109][31][31][2] )

o_array = np.array(images_list[0])
q_array = np.array(images_list[1])
G_array = np.array(images_list[2])
n8_array = np.array(images_list[3])

print(o_array.shape, q_array.shape, G_array.shape, n8_array.shape)
image2 = Image.fromarray(o_array[109])
pyplot.imshow(image2)
# Out:
# Numebr of images in Sample051 :  110
# Numebr of images in Sample053 :  2
# Numebr of images in Sample017 :  77
# Numebr of images in Sample009 :  10
# RGB??:  191 192 186
# (110, 32, 32, 3) (2, 32, 32, 3) (77, 32, 32, 3) (10, 32, 32, 3)

# %%
play = np.copy(o_array[100]) # One image to play with
print(play.shape) # Shape of the image
print(play[3].shape) # Shape of the 3rd row of pixels ?
print(play[3][31].shape) #Shape of the 3rd row's 31st pixel ?

# I want to try playing with color channels
# All rows, all columns (All pixels)
# EH EL HABAL DAAAAAAAH 
play [:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:][:] = 100
image2 = Image.fromarray(play)
pyplot.imshow(image2)
# Out:
# (32, 32, 3)
# (32, 3)
# (3,)

# %%
print ( len(images_list[0][100][0][0]) )
play2 = images_list[0][100]
#These are supposedly the list of the values of the 1st channel of all the pixels ?? bs homa leh 3 values nakitai :(((
print( "Msh fahmaa :"")" , play2[:][:][:][:][:][:])   # 3AAAAAAAAAAAAAAAAAA
image3 = Image.fromarray(play2)
pyplot.imshow(image3)
# Out:
# 3
# Msh fahmaa :) [[[160 192 239]
#   [159 190 236]
#   [158 190 235]
#   ...
#   [131 176 231]
#   [131 176 231]
#   [130 175 230]]
#
#  [[159 190 237]
#   [162 189 236]
#   [161 192 238]
#   ...
#   [129 173 229]
#   [128 173 228]
#   [131 175 231]]
#
#  [[159 191 238]
#   [161 191 238]
#   [161 192 238]
#   ...
#   [128 174 226]
#   [128 174 227]
#   [130 176 228]]
#
#  ...
#
#  [[ 70 111 202]
#   [ 64 111 199]
#   [ 64 112 195]
#   ...
#   [ 40 108 198]
#   [ 45 114 206]
#   [ 49 122 209]]
#
#  [[ 56 114 204]
#   [ 63 119 207]
#   [ 55 114 200]
#   ...
#   [ 38 112 202]
#   [ 37 114 203]
#   [ 40 120 208]]
#
#  [[ 41 114 203]
#   [ 45 111 199]
#   [ 42 112 201]
#   ...
#   [ 32 112 201]
#   [ 31 114 201]
#   [ 30 116 205]]]

# %% [markdown]
# #### - The next step is reading and preprocessing the images
#      . Use the skimage package
#      . Resize the images to a common size. <-- Resized while uploading to (32,32)
#      . For questions 1.2 and 1.3, work with grayscale images.

# %%
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

original = o_array[100]
grayscale = rgb2gray(original)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(grayscale, cmap=plt.cm.gray)
ax[1].set_title("Grayscale")

fig.tight_layout()
plt.show()

# %%
o_list_grayscale = []
# o_array_grayscale = np.empty([110,32,32,1])
# print(o_array_grayscale.shape)

for i in range (0, o_array.shape[0]):
    # o_array_grayscale = np.insert(o_array_grayscale[i], i,rgb2gray(o_array[i]))
    gray = rgb2gray(o_array[i])
    o_list_grayscale.append(gray)
    pyplot.imshow(gray, cmap=plt.cm.gray)
    pyplot.show()


o_list_grayscale[100][31][0]

o_array_grayscale = np.array (o_list_grayscale)
o_array_grayscale.shape
# Out:
# (110, 32, 32)

# %%
q_list_grayscale = []
G_list_grayscale = []
n8_list_grayscale = []

for i in range (0, q_array.shape[0]):
    gray = rgb2gray(q_array[i])
    q_list_grayscale.append(gray)
q_array_grayscale = np.array (q_list_grayscale)
    
for i in range (0, G_array.shape[0]):
    gray = rgb2gray(G_array[i])
    G_list_grayscale.append(gray)
G_array_grayscale = np.array (G_list_grayscale)
    
for i in range (0, n8_array.shape[0]):
    gray = rgb2gray(n8_array[i])
    n8_list_grayscale.append(gray)
n8_array_grayscale = np.array (n8_list_grayscale)

# %%
### Normalization trial 

normalized_q = np.ndarray(shape = (q_array.shape[0], 32, 32, 3)).astype(np.float32)
for i in range(q_array.shape[0]):
    normalized_q[i] = (q_array[i] - 128.0) / 128.0
# bs this should be done 3ala el training set bs msh el test kaman, fa let's do it after splitting the freakin data

# %% [markdown]
# #### - Organize your data into training, validation and test set.
#     Training: 60%
#     Validation: 20%
#     Test: 20%

# %%
import pandas as pd

X = np.concatenate([o_array_grayscale, q_array_grayscale, G_array_grayscale, n8_array_grayscale])
print (X.shape)
y = np.zeros (o_array_grayscale.shape[0]+ q_array_grayscale.shape[0]+ G_array_grayscale.shape[0]+n8_array_grayscale.shape[0])
print(y.shape)
y[0:110] = 0 # For "o" 110 pics
y[110:112] = 1 # For "q" 2 pics
y[112:189] = 2 # For G 77 pics
y[189:199] = 3 # For n8 10 pics
# Out:
# (199, 32, 32)
# (199,)

# %%
from sklearn.utils import shuffle

X, y= shuffle(X, y)
X.shape, y.shape
# Out:
# ((199, 32, 32), (199,))

# %%
# Test the shuffle
pyplot.imshow(X[100], cmap=plt.cm.gray)
pyplot.show()
print(y[100])
(unique, counts) = np.unique(y, return_counts=True)
print((unique, counts))
# Out:
# 3.0
# (array([0., 1., 2., 3.]), array([110,   2,  77,  10]))

# %% [markdown]
# #### Great ! Insha'allah this means that the shuffling worked

# %%
# Now split ! 
# There's a class with very few examples, should we use the stradified now? I guess yes !
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)# , stratify=y)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, train_size=0.5, random_state=42)#, stratify=y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
# bin_clf = LogisticRegression(max_iter=10, tol=0.1, solver='liblinear')

# bin_clf.fit(X_train, y_train)

sgd_clf = SGDClassifier(random_state=42, max_iter=1000, tol=1e-3)
sgd_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-296-ae06e2d4beb0> in <module>
#       6
#       7 sgd_clf = SGDClassifier(random_state=42, max_iter=1000, tol=1e-3)
# ----> 8 sgd_clf.fit(X_train, y_train)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     727             Returns an instance of self.
#     728         """
# --> 729         return self._fit(X, y, alpha=self.alpha, C=1.0,
#     730                          loss=self.loss, learning_rate=self.learning_rate,
#     731                          coef_init=coef_init, intercept_init=intercept_init,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from skimage.feature import hog
class HogTransformer(BaseEstimator, TransformerMixin):
    """
    Expects an array of 2d arrays (1 channel images)
    Calculates hog features for each img
    """
 
    def __init__(self, y=None, orientations=9,
                 pixels_per_cell=(8, 8),
                 cells_per_block=(3, 3), block_norm='L2-Hys'):
        self.y = y
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        self.block_norm = block_norm
 
    def fit(self, X, y=None):
        return self
 
    def transform(self, X, y=None):
 
        def local_hog(X):
            return hog(X,
                       orientations=self.orientations,
                       pixels_per_cell=self.pixels_per_cell,
                       cells_per_block=self.cells_per_block,
                       block_norm=self.block_norm)
 
        try: # parallel
            return np.array([local_hog(img) for img in X])
        except:
            return np.array([local_hog(img) for img in X])

# %%
hogify = HogTransformer(
    pixels_per_cell=(14, 14), 
    cells_per_block=(2,2), 
    orientations=9, 
    block_norm='L2-Hys'
)
X_train_hog = hogify.fit_transform(X_train)

# %%
bin_clf = LogisticRegression(max_iter=100, tol=.01, solver='liblinear')
bin_clf.fit(X_train_hog, y_train)
bin_clf.score(X_train_hog, y_train)
# Out:
# 0.697841726618705

# %%
X_test_hog = hogify.fit_transform(X_test)

# %%
bin_clf.score(X_test_hog, y_test)
# Out:
# 0.7

# %%
from sklearn.metrics import confusion_matrix

y_pred = bin_clf.predict(X_test_hog)
confusion_matrix(y_test, y_pred)
# Out:
# array([[16,  2,  0],
#        [ 6,  5,  0],
#        [ 1,  0,  0]])

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(bin_clf, X_test_hog, y_test)  
plt.show()

# %%
TP, TN, FP, FN = # omg it's multiclass of 4 classes and one of them is dead :@
Accuracy =
Recall = 
Percision =

# %%
from sklearn import metrics
metrics.plot_roc_curve(bin_clf, X_test_hog, y_test) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-320-7b20751764ac> in <module>
#       1 from sklearn import metrics
# ----> 2 metrics.plot_roc_curve(bin_clf, X_test_hog, y_test)
#       3 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/roc_curve.py in plot_roc_curve(estimator, X, y, sample_weight, drop_intermediate, response_method, name, ax, pos_label, **kwargs)
#     210     check_matplotlib_support('plot_roc_curve')
#     211
# --> 212     y_pred, pos_label = _get_response(
# ...

# %% [markdown]
# # TP, TN, FP, FN = tp, tn, fp, fn
# Accuracy = (TP + TN) / (TP + TN + FP + FN)
# Recall = TP / (TP + FN)
# Percision =  TP / (TP + FP)
